# %% [markdown]
# ## CONDITIONAL GENERATION EXAMPLES

# %%
from generate import generate_conditionally

# %%
generate_conditionally('Good morning everyone', save_figure_name='generation1')
# Out:
# Image saved as generation1

# %%
generate_conditionally('This is my Handwriting project', save_figure_name='generation2')
# Out:
# Image saved as generation2

# %%
generate_conditionally('Look at the code', save_figure_name='generation3')
# Out:
# Image saved as generation3

# %% [markdown]
# ## RANDOM GENERATION EXAMPLE

# %%
from generate import generate_unconditionally

# %%
generate_unconditionally(random_seed=20)
